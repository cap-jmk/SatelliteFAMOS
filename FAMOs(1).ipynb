# %%
# !git clone https://github.com/MQSchleich/SatelliteFAMOS

# %% [markdown]
# # Set-Up
# 1.  Install Anaconda package manager
# 2.  Move the directory to your drive in order to save the images later

# %%
# !wget https://repo.anaconda.com/archive/Anaconda3-5.2.0-Linux-x86_64.sh && bash Anaconda3-5.2.0-Linux-x86_64.sh -bfp /usr/local

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# !cd "/content/drive/My Drive/Colab Notebooks/SatelliteFAMOS"
# !sudo apt-get install libopenblas-dev
# !conda install numpy  pygpu theano joblib pytorch -c pytorch
# !pip install torchvision
# !pip install --upgrade https://github.com/Lasagne/Lasagne/archive/master.zip

# %%
# !pip install tqdm msgpack
# !pip install pillow
# !pip install matplotlib

# %%
# %cd "/content/drive/My Drive/Colab Notebooks/SatelliteFAMOS"
#!THEANO_FLAGS='floatX=float32,device=cuda0,gpuarray.preallocate=1' python sgan.py
# !python  mosaicFAMOS.py  --texturePath=samples/milano/ --contentPath=samples/archimboldo/ --N=80 --nBlocks=1 --dIter=2 --WGAN=True
